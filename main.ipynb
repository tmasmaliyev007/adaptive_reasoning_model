# %%
from huggingface_hub import snapshot_download

# %%
snapshot_download(
    "taharmasmaliyev07/Stage1-BF16-EPOCH3",
    local_dir="test"
)
# Out:
# ...
# Fetching 2 files:   0%|          | 0/2 [00:00<?, ?it/s]
# '/home/tmasmaliyev/Documents/ADA_University/Master_thesis/Workspace/test'
